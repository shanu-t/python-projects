# %%
# A PROJECT REPORT ON SALES
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\dell\Downloads\Financial_Sample.xlsx")
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                       NaN  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df = pd.read_excel(r"C:\Users\dell\Downloads\Financial_Sample.xlsx")
df.head(3)
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera           NaN      1618.5
# 1  Government  Germany  Carretera           NaN         NaN
# 2   Midmarket   France  Carretera           NaN      2178.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3        20.0      32370.0        0.0  32370.0  16185.0
# 1                    3         NaN      26420.0        0.0  26420.0  13210.0
# 2                    3        15.0      32670.0        0.0  32670.0  21780.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# 1  13210.0 2014-01-01             1    January  2014
# 2  10890.0 2014-06-01             6       June  2014

# %%
df = pd.read_excel(r"C:\Users\dell\Downloads\Financial_Sample.xlsx")
df.tail(5)
# Out:
#               Segment                   Country   Product Discount Band  \
# 695    Small Business                    France  Amarilla          High
# 696    Small Business                    Mexico  Amarilla          High
# 697        Government                    Mexico   Montana          High
# 698        Government                    Canada     Paseo          High
# 699  Channel Partners  United States of America       VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 695      2475.0                  260       300.0     742500.0  111375.00
# 696       546.0                  260       300.0     163800.0   24570.00
# 697      1368.0                    5         7.0       9576.0    1436.40
# 698       723.0                   10         7.0       5061.0     759.15
# 699      1806.0                  250        12.0      21672.0    3250.80
#
#          Sales      COGS    Profit       Date  Month Number Month Name  Year
# ...

# %%
df = pd.read_excel(r"C:\Users\dell\Downloads\Financial_Sample.xlsx")
df.isnull().sum()
# Out:
# Segment                 0
# Country                 3
# Product                 1
# Discount Band          54
# Units Sold              1
# Manufacturing Price     0
# Sale Price              1
# Gross Sales             0
# Discounts               0
#  Sales                  0
# COGS                    0
# Profit                  0
# Date                    0
# Month Number            0
# Month Name              0
# Year                    0
# dtype: int64

# %%
df = pd.read_excel(r"C:\Users\dell\Downloads\Financial_Sample.xlsx")
df.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   699.000000           700.000000  699.000000  7.000000e+02
# mean   1608.705293            96.477143  118.569385  1.827594e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1545.000000            10.000000   20.000000  3.798000e+04
# 75%    2230.750000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
# std     867.980791           108.602612  136.822671  2.542623e+05
#
#            Discounts         Sales           COGS         Profit  \
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# 25%       800.320000  1.592800e+04    7490.000000    2805.960000
# ...

# %%
df = pd.read_excel(r"C:\Users\dell\Downloads\Financial_Sample.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              697 non-null    object
#  2   Product              699 non-null    object
#  3   Discount Band        646 non-null    object
#  4   Units Sold           699 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           699 non-null    float64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
df.isnull().sum().sum()/df.size*100
# Only one% data is null (almost)
# Out:
# np.float64(0.5357142857142857)

# %%
df.select_dtypes(include="object")
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera           NaN
# 1          Government                   Germany  Carretera           NaN
# 2           Midmarket                    France  Carretera           NaN
# 3           Midmarket                       NaN  Carretera           NaN
# 4           Midmarket                    Mexico  Carretera           NaN
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#     Month Name
# 0      January
# 1      January
# 2         June
# 3         June
# ...

# %%
df.select_dtypes(include="object").isnull().sum()
# Out:
# Segment           0
# Country           3
# Product           1
# Discount Band    54
# Month Name        0
# dtype: int64

# %%
df["Country"].mode()
# Out:
# 0    Canada
# 1    France
# Name: Country, dtype: object

# %%
#Fill null values of objects by mode values
def fillObj(obj):
    df[obj]=df[obj].fillna(df[obj].mode()[0])
for ob in df.select_dtypes(include="object"):
    fillObj(ob)
df.select_dtypes(include="object").isnull().sum()
# Out:
# Segment          0
# Country          0
# Product          0
# Discount Band    0
# Month Name       0
# dtype: int64

# %%
# Replace null values of float64 by mean values
df.select_dtypes(include="float64").isnull().sum()
# Out:
# Units Sold     1
# Sale Price     1
# Gross Sales    0
# Discounts      0
#  Sales         0
# COGS           0
# Profit         0
# dtype: int64

# %%
# Fill null values of float64 by mean values
def fillfloat(obj):
    df[obj]=df[obj].fillna(df[obj].mean())
for ob in df.select_dtypes("float64"):
    fillfloat(ob)
df.select_dtypes(include="float64").isnull().sum()
# Out:
# Units Sold     0
# Sale Price     0
# Gross Sales    0
# Discounts      0
#  Sales         0
# COGS           0
# Profit         0
# dtype: int64

# %%
# Total null values in DataFrame
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.head(3)
# Out:
#       Segment  Country    Product Discount Band   Units Sold  \
# 0  Government   Canada  Carretera          High  1618.500000
# 1  Government  Germany  Carretera          High  1608.705293
# 2   Midmarket   France  Carretera          High  2178.000000
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3   20.000000      32370.0        0.0  32370.0  16185.0
# 1                    3  118.569385      26420.0        0.0  26420.0  13210.0
# 2                    3   15.000000      32670.0        0.0  32670.0  21780.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# 1  13210.0 2014-01-01             1    January  2014
# 2  10890.0 2014-06-01             6       June  2014

# %%
df["Month Name"].unique()
# Out:
# array(['January', 'June', 'December', 'March', 'July', 'August',
#        'September', 'October', 'February', 'November', 'April', 'May'],
#       dtype=object)

# %%
# X values for plotting
XMonth = ['January','February','March','April','May','June','July', 'August',
       'September', 'October', 'November','December']

# %%
# Y values for plotting 
Yprofit = []
for mon in XMonth:
    pass
df.shape[0]
# Out:
# 700

# %%
# Y values for plotting 
Yprofit = []
for mon in XMonth:
    total =0
    for index in range (0,df.shape[0]):
        if(df["Month Name"][index]==mon):
            total=total+df["Profit"][index]

    Yprofit.append(total)
Yprofit
# Out:
# [np.float64(814028.6799999999),
#  np.float64(1148547.39),
#  np.float64(669866.87),
#  np.float64(929984.5699999998),
#  np.float64(828640.06),
#  np.float64(1473753.8200000003),
#  np.float64(923865.6799999998),
#  np.float64(791066.4199999999),
#  np.float64(1786735.2699999996),
#  np.float64(3439781.0200000014),
#  np.float64(1370102.5),
#  np.float64(2717329.979999999)]

# %%
# Values for plotting
XMonth =[]
for a in range (1,13):
    XMonth.append(a)

XMonth
plt.plot(XMonth,Yprofit)

# %%
# X values for plotting
XMonth = ['January','February','March','April','May','June','July', 'August',
       'September', 'October', 'November','December']

for index in range(0,len(XMonth)):
    XMonth[index]=XMonth[index][0:3]
XMonth
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
# Y values for plotting (Calculating profit by Months)
Yprofit = []
YGS = []
for mon in XMonth:
    totalProfit = 0
    totalGS = 0
    for index in range (0,df.shape[0]):
        if(df["Month Name"][index][0:3]==mon):
            total=total+df["Profit"][index]
        if(df["Month Name"][index][0:3]==mon):
            totalGS=totalGS+df["Gross Sales"][index]

    Yprofit.append(total)
    YGS.append(totalGS)
Yprofit
YGS
# Out:
# [np.float64(7307403.5),
#  np.float64(7699201.0),
#  np.float64(6124026.0),
#  np.float64(7429392.5),
#  np.float64(6767911.0),
#  np.float64(10268972.0),
#  np.float64(8833027.5),
#  np.float64(6325959.0),
#  np.float64(11575053.0),
#  np.float64(23142112.0),
#  np.float64(14115248.0),
#  np.float64(18343293.0)]

# %%
plt.plot(XMonth,Yprofit)
plt.show()

# %%
plt.plot(XMonth,Yprofit)
plt.title("Profit By Month")
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(XMonth,Yprofit)
plt.title("Profit By Month")
plt.show()

# %%
plt.subplot(2,1,2)
plt.bar(XMonth,Yprofit)
plt.title("Profit By Month")
plt.subplot(2,1,1)
plt.bar(XMonth,YGS)
plt.title("Gross Sale By Month")
plt.show()

# %%
# profit Percentage
profit = sum(Yprofit)/sum(YGS)*100
Expence = 100-profit
plt.pie([profit,Expence])
plt.title("Profit And Expence")
plt.show()
